# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
df = pd.read_excel('gdrive/My Drive/Colab Notebooks/stp.xlsx')

# %%
df.head()
# Out:
#                                              Context  Class
# 0  কোনো কিছু বোঝার আগে'ই তপুর জীবনটা হঠাত করে পাল...      0
# 1  নিঃসঙ্গ কিশোরের এই দুঃসহ জীবনে বন্ধুত্বের হাত ...      1
# 2  আম্মু চিৎকার করে বললেন, ভুল বলেছি আমি? তোদের আ...      1
# 3  পথের পাশে ভাঙ্গা দেয়ালটায় হেলান দিয়ে বসে আছেন ...      0
# 4  দুলি খালা গলা নামিয়ে ফিসফিস করে বলতো, তার অর্থ...      1

# %%
df.isnull().sum()
# Out:
# Context    0
# Class      0
# dtype: int64

# %%
df['Context'].value_counts()
# Out:
# অবাঙালি বন্ধুরা মজা করে বলেন ,"তোমাদের বাঙলা ভাষা খুব মজার"।\n"কেন" ? "তোমরা বল জল খাচ্ছি। আরে, জল কী খাওয়া যায় "?                                                                                                                                                                    2
# আর খাবে নাই বা কেন ? আর কোন্ ভাষায় কোন্  কবি খাওয়া নিয়ে  সাড়ম্বরে কবিতা লিখেছেন ?                                                                                                                                                                                                     2
# প্রধানমন্ত্রী কি বিমান হেলিকাপ্টারে যাতায়াত করবেন না? \nসময় সংকুলানের জন‍্য? যুদ্ধক্ষেত্রে কি মালবাহী বিমান বহর ব‍্যবহার হবে না?\n দরকারে সাধারণ সৈনিকরাও বিমানে চড়বে না?                                                                                                             1
# কেউ কেউ  চুপিচুপি  'টাকা খায়' , পকেটমার ধরা পড়ে 'মার খায়', কারা যেন  'ঘুষ খায়' !\n  ভীড়ের মধ্যে 'ধাক্কা খায়' । ফুটবল মাঠে 'গোল খায় '!                                                                                                                                                 1
# ভয়ে ভয়ে গর্তের কাছে আস্তে আস্তে মুখ লইয়া গিয়া দেখিলেন, \nঅনতিউচ্চ কক্ষের মধ্যে জলের স্রোত প্রবাহিত হইতেছে-- \nঅন্ধকারে আর বিশেষ কিছু দেখিতে পাইলেন না!                                                                                                                                1
#                                                                                                                                                                                                                                                                                      ..
# এতো ভারি বিপদ! সারা পৃথিবীতে এত নাম থাকতে আমার নাম নিয়ে এরকম নখরা কেন রে বাবা?                                                                                                                                                                                                        1
# প্রায় পাঁচ ছয় বাড়িতে বাসন মাজা, কাপড় কাচা, ঘর ঝাড়ামোছা সেরে, সব শেষে স্যান্যাল বাড়ি।\n   বেলা তখন প্রায় বারোটা ছুঁই ছুঁই। সেখান থেকে ছুটি মিলবে বিকেল চারটেয়,বৌদি স্কুল থেকে ফেরার পরে।\n এই এতটা লম্বা সময় বস্তির ঘরে পটলাকে কার কাছে রেখে বেরোবে মিনতি?                             1
# একদিক টেক্কা সাহেব গোলাম আসিয়া রাজপুত্র কোটালের পুত্র এবং সদাগরের পুত্রকে\n হাঁড়ির মতো গলা করিয়া অবিচলিত গম্ভীরমুখে জিজ্ঞাসা করিল, \nতোমরা বিধানমতে চলিতেছ না কেন।তিন বন্ধু উত্তর করিল, \nআমাদের ইচ্ছা।হাঁড়ির মতো গলা করিয়া তাসরাজ্যের তিন অধিনায়ক স্বপ্নাভিভূতের মতো বলিল, ইচ্ছা?    1
# দিনের পর দিন আমি যেন ছোট হয়ে যেতে থাকলাম।\nআর চারপাশের সবকিছু বড় হয়ে যেতে লাগলো।ঘরবাড়ী , \nমানুষজন এমন কি রাস্তার কুকুরটা পর্যন্ত আমার থেকে লম্বা হয়ে যাচ্ছিলো।\nআমি যেন রাস্তার সাথে মিশে যাচ্ছিলাম।পিঁপড়ের মতো!                                                                     1
# গালি দিতে মন চাইলে বাংলা বা ইংলিশে দিলেও পারতেন।\n সংস্কৃত ভাষায় গালাগালির কি দরকার ছিলো?                                                                                                                                                                                             1
# Name: Context, Length: 150, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df['Class'].plot(kind='hist')

# %%
df['Length'] = df['Context'].str.split().apply(len)
df.head(20)
# Out:
#                                               Context  Class  Length
# 0   কোনো কিছু বোঝার আগে'ই তপুর জীবনটা হঠাত করে পাল...      0      28
# 1   নিঃসঙ্গ কিশোরের এই দুঃসহ জীবনে বন্ধুত্বের হাত ...      1      26
# 2   আম্মু চিৎকার করে বললেন, ভুল বলেছি আমি? তোদের আ...      1      35
# 3   পথের পাশে ভাঙ্গা দেয়ালটায় হেলান দিয়ে বসে আছেন ...      0      53
# 4   দুলি খালা গলা নামিয়ে ফিসফিস করে বলতো, তার অর্থ...      1      44
# 5   রফিক সাহেব মেঘের মতো গলায় বললেন, বাসে মেয়েরা স...      1      28
# 6   প্রিন্সিপাল ম্যাডাম আমাকে ডেকে একদিন জিজ্ঞেস ক...      0      47
# 7   পরীক্ষার হল থেকে'ই বের আমার প্রিয়াংকার সাথে দে...      1      31
# 8   আমাদের ক্লাসের দুই ভালো ছাত্র জয়ন্ত আর মামুন ন...      1      52
# 9   প্রিয়াংকা কোনো কথা না বলে আমার দিকে কিছুক্ষণ ত...      1      30
# 10  আমরা সবাই তখন দরজার কাছে ভীড় করে দাঁড়ালাম। উত্...      0      41
# 11  খুব মন খারাপ করে  একদিন আমি হাসপাতালের বারান্দ...      1      30
# 12  ডাক্তার ভদ্র মহিলা কিছুক্ষণ আমার দিকে তীক্ষ্ণচ...      0      24
# 13  মা মারা গেছেন বলে তো আমি হাসছিলাম না। অনেক দিন...      0      50
# 14  মুক্তি? তার আসার পথও যে একরকম নয়। কারো স্লোগান...      0      34
# 15  নিজের খাঁচা থেকে বেরুবার জন্যে তার ডানা ঝাপটান...      1      29
# 16  বর্তমান চাকরীর বাজারে দক্ষতার বিকল্প নেই। শিক্...      1      33
# 17  ঋণ স্বীকারে অগৌরবের কিছু নেই। মহান জাতি এবং মহ...      0      39
# 18  বীরশ্রেষ্ঠ তালিকার দিকে আমি প্রায়'ই তাকাই। ছোট...      1      50
# 19  ইরতাজউদ্দিন গম্ভীর গলায় বললেন, ব্যাপারটা কি? আ...      1      25

# %%
df.Length.describe()
# Out:
# count    152.000000
# mean      27.342105
# std        9.581374
# min       11.000000
# 25%       20.000000
# 50%       26.500000
# 75%       32.000000
# max       57.000000
# Name: Length, dtype: float64

# %%
import string 
def remove_punc(s):
    table = str.maketrans({key: None for key in string.punctuation})
    return s.translate(table)

# %%
x = df['Context'].fillna(' ')
y = df['Class']
print(x.head())
print(y.head())
# Out:
# 0    কোনো কিছু বোঝার আগে'ই তপুর জীবনটা হঠাত করে পাল...
# 1    নিঃসঙ্গ কিশোরের এই দুঃসহ জীবনে বন্ধুত্বের হাত ...
# 2    আম্মু চিৎকার করে বললেন, ভুল বলেছি আমি? তোদের আ...
# 3    পথের পাশে ভাঙ্গা দেয়ালটায় হেলান দিয়ে বসে আছেন ...
# 4    দুলি খালা গলা নামিয়ে ফিসফিস করে বলতো, তার অর্থ...
# Name: Context, dtype: object
# 0    0
# 1    1
# 2    1
# 3    0
# 4    1
# Name: Class, dtype: int64

# %%
x = df['Context'].apply(remove_punc)
x.shape
# Out:
# (152,)

# %%
contractions = { 
"বি.দ্র ": "বিশেষ দ্রষ্টব্য",
"ড.": "ডক্টর",
"ডা.": "ডাক্তার",
"ইঞ্জি:": "ইঞ্জিনিয়ার",
"রেজি:": "রেজিস্ট্রেশন",
"মি.": "মিস্টার",
"মু.": "মুহাম্মদ",
"মো.": "মোহাম্মদ",
}

# %%
import re
import string
from collections import Counter
vocab = Counter()
def clean_text(x,remove_stopwords = False):
    if True:
        new_text = []
        for word in x:
            if word in contractions:
                new_text.append(contractions[word])
            else:
                new_text.append(word)
        x = "".join(new_text)
    # Format words and remove unwanted characters
    whitespace = re.compile(u"[\s\u0020\u00a0\u1680\u180e\u202f\u205f\u3000\u2000-\u200a]+", re.UNICODE)
    bangla_digits = u"[\u09E6\u09E7\u09E8\u09E9\u09EA\u09EB\u09EC\u09ED\u09EE\u09EF]+"
    english_chars = u"[a-zA-Z0-9]"
    punc = u"[(),$%^&*+={}\[\]:\"|\'\~`<>/,¦!?½£¶¼©⅐⅑⅒⅓⅔⅕⅖⅗⅘⅙⅚⅛⅜⅝⅞⅟↉¤¿º;-]+"
    bangla_fullstop = u"\u0964"     #bangla fullstop(dari)
    punctSeq   = u"['\"“”‘’]+|[.?!,…]+|[:;]+"
    
    x = re.sub(bangla_digits, " ", x)
    x = re.sub(punc, " ", x)
    x = re.sub(english_chars, " ", x)
    x = re.sub(bangla_fullstop, " ", x)
    x = re.sub(punctSeq, " ", x)
    x = whitespace.sub(" ", x).strip()
    
    x = re.sub(r'https?:\/\/.*[\r\n]*', '', x, flags=re.MULTILINE)
    x = re.sub(r'\<a href', ' ', x)
    x = re.sub(r'&amp;‘:‘ ’', '', x) 
    x = re.sub(r'[_"\-;%()|+&=*%.,!?:#$@\[\]/]। ,', ' ', x)
    x = re.sub(r'<br />', ' ', x)
    x = re.sub(r'\'', ' ', x)
    x = re.sub(r"[\@$#%~+-\.\'।\"]"," ",x)
    x = re.sub(r"(?m)^\s+", "", x)
    x = re.sub("[()]","",x)
    x = re.sub("[‘’]","",x)
    x = re.sub("[!]","",x)
    x = re.sub("[/]","",x)
    x = re.sub("[:]","",x)
    x = re.sub('\ |\?|\.|\!|\/|\;|\:', ' ',x)
    x = x.strip("/")
    
    if remove_stopwords:
        k = []
        with open('/content/Banglastopword.txt', 'r',encoding="utf-8") as f:
            for word in f:
                word = word.split()
                k.append(word[0])
            x = [t for t in x if t not in k]
            x = "".join(x)
   

    return x

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.corpus import stopwords
import string
import math
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
# %matplotlib inline

# %%
vocab = CountVectorizer(analyzer=clean_text,encoding='utf-8').fit(x)

# %%
print(len(vocab.vocabulary_))
# Out:
# 64

# %%
r0 = x[87]
print(r0)
# Out:
# বৈদ্যনাথের মনে হইল তিনি মরিতে যাইতেছেন।
# ছেলেদের কোলে করিয়া চুম্বন করিয়া সাশ্রুনেত্রে বাড়ি হইতে বাহির হইলেন। তখন মোক্ষদাও কাঁদিতে লাগিলেন

# %%
vocab0 = vocab.transform([r0])
print(vocab0)
# Out:
#   (0, 0)	19
#   (0, 1)	1
#   (0, 6)	4
#   (0, 12)	1
#   (0, 14)	5
#   (0, 15)	1
#   (0, 16)	1
#   (0, 19)	1
#   (0, 20)	2
#   (0, 29)	7
#   (0, 30)	1
#   (0, 31)	4
#   (0, 33)	9
#   (0, 36)	4
#   (0, 38)	4
#   (0, 39)	2
#   (0, 40)	8
#   (0, 41)	6
#   (0, 42)	1
#   (0, 43)	1
#   (0, 44)	1
#   (0, 45)	4
#   (0, 47)	10
#   (0, 48)	9
#   (0, 50)	2
#   (0, 53)	15
#   (0, 54)	1
#   (0, 55)	2
#   (0, 57)	5
#   (0, 59)	1
#   (0, 61)	2

# %%
print(vocab.get_feature_names()[50])
print(vocab.get_feature_names()[50])
# Out:
# ু
# ু

# %%
x = vocab.transform(x)

# %%
print("Shape of the sparse matrix: ", x.shape)
print("Non-Zero occurences: ",x.nnz)
density = (x.nnz/(x.shape[0]*x.shape[1]))*100
print("Density of the matrix = ",density)
# Out:
# Shape of the sparse matrix:  (152, 64)
# Non-Zero occurences:  5008
# Density of the matrix =  51.48026315789473

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.15,random_state=101)

# %%
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB()
mnb.fit(x_train,y_train)
predmnb = mnb.predict(x_test)
print("Confusion Matrix for Multinomial Naive Bayes:")
print(confusion_matrix(y_test,predmnb))
print("Score:",round(accuracy_score(y_test,predmnb)*100,2))
print("Classification Report:",classification_report(y_test,predmnb))
# Out:
# Confusion Matrix for Multinomial Naive Bayes:
# [[7 3]
#  [7 6]]
# Score: 56.52
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.50      0.70      0.58        10
#            1       0.67      0.46      0.55        13
#
#     accuracy                           0.57        23
#    macro avg       0.58      0.58      0.56        23
# weighted avg       0.59      0.57      0.56        23

# %%
acc1=metrics.accuracy_score(y_test, predmnb)
print("Accuracy:",acc1*100,"%")
# Out:
# Accuracy: 56.52173913043478 %

# %%
from sklearn.ensemble import RandomForestClassifier
rmfr = RandomForestClassifier()
rmfr.fit(x_train,y_train)
predrmfr = rmfr.predict(x_test)
print("Confusion Matrix for Random Forest Classifier:")
print(confusion_matrix(y_test,predrmfr))
print("Score:",round(accuracy_score(y_test,predrmfr)*100,2))
print("Classification Report:",classification_report(y_test,predrmfr))
# Out:
# Confusion Matrix for Random Forest Classifier:
# [[8 2]
#  [4 9]]
# Score: 73.91
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73        10
#            1       0.82      0.69      0.75        13
#
#     accuracy                           0.74        23
#    macro avg       0.74      0.75      0.74        23
# weighted avg       0.75      0.74      0.74        23

# %%
acc2=metrics.accuracy_score(y_test,predrmfr)
print("Accuracy:",acc2*100,"%")
# Out:
# Accuracy: 73.91304347826086 %

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
preddt = dt.predict(x_test)
print("Confusion Matrix for Decision Tree:")
print(confusion_matrix(y_test,preddt))
print("Score:",round(accuracy_score(y_test,preddt)*100,2))
print("Classification Report:",classification_report(y_test,preddt))
# Out:
# Confusion Matrix for Decision Tree:
# [[8 2]
#  [7 6]]
# Score: 60.87
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.53      0.80      0.64        10
#            1       0.75      0.46      0.57        13
#
#     accuracy                           0.61        23
#    macro avg       0.64      0.63      0.61        23
# weighted avg       0.66      0.61      0.60        23

# %%
acc3=metrics.accuracy_score(y_test,preddt)
print("Accuracy:",acc3*100,"%")
# Out:
# Accuracy: 60.86956521739131 %

# %%
from sklearn.svm import SVC
svm = SVC(random_state=101)
svm.fit(x_train,y_train)
predsvm = svm.predict(x_test)
print("Confusion Matrix for Support Vector Machines:")
print(confusion_matrix(y_test,predsvm))
print("Score:",round(accuracy_score(y_test,predsvm)*100,2))
print("Classification Report:",classification_report(y_test,predsvm))
# Out:
# Confusion Matrix for Support Vector Machines:
# [[ 1  9]
#  [ 2 11]]
# Score: 52.17
# Classification Report:               precision    recall  f1-score   support
#
#            0       0.33      0.10      0.15        10
#            1       0.55      0.85      0.67        13
#
#     accuracy                           0.52        23
#    macro avg       0.44      0.47      0.41        23
# weighted avg       0.46      0.52      0.44        23

# %%
import pickle
acc4=metrics.accuracy_score(y_test,predsvm)
print("Accuracy:",acc4*100,"%")
# Out:
# Accuracy: 52.17391304347826 %

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
predknn = knn.predict(x_test)
print("Confusion Matrix for K Neighbors Classifier:")
print(confusion_matrix(y_test,predknn))
print("Score: ",round(accuracy_score(y_test,predknn)*100,2))
print("Classification Report:")
print(classification_report(y_test,predknn))
# Out:
# Confusion Matrix for K Neighbors Classifier:
# [[5 5]
#  [4 9]]
# Score:  60.87
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.50      0.53        10
#            1       0.64      0.69      0.67        13
#
#     accuracy                           0.61        23
#    macro avg       0.60      0.60      0.60        23
# weighted avg       0.60      0.61      0.61        23

# %%
acc5=metrics.accuracy_score(y_test,predknn)
print("Accuracy:",acc5*100,"%")
# Out:
# Accuracy: 60.86956521739131 %

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(x_train,y_train)
predxgb = xgb.predict(x_test)
print("Confusion Matrix for xgboost Classifier:")
print(confusion_matrix(y_test,predxgb))
print("Score: ",round(accuracy_score(y_test,predxgb)*100,2))
print("Classification Report:")
print(classification_report(y_test,predxgb))
# Out:
# Confusion Matrix for xgboost Classifier:
# [[8 2]
#  [6 7]]
# Score:  65.22
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67        10
#            1       0.78      0.54      0.64        13
#
#     accuracy                           0.65        23
#    macro avg       0.67      0.67      0.65        23
# weighted avg       0.69      0.65      0.65        23

# %%
acc6=metrics.accuracy_score(y_test,predxgb)
print("Accuracy:",acc6*100,"%")
# Out:
# Accuracy: 65.21739130434783 %

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ('NB','RF','DT','SVM','KNN','XGB')
y_pos = np.arange(len(objects))
performance = [acc1,acc2,acc3,acc4,acc5,acc6]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Score')
plt.title('Best Accuracy')

plt.show()

# %%
headline=input()
prt=vocab.transform([headline])
# Out:
# 3

# %%
m1=svm.predict(prt)
print("Predicted Rating:",m1)
if m1==0:
  print("Exclamatory")
else:
  print("Interogartive")
# Out:
# Predicted Rating: [1]
# Interogartive

# %%
m2=knn.predict(prt)
print("Predicted Rating:",m2)
if m2==0:
  print("Exclamatory")
else: 
  print("Interogartive")
# Out:
# Predicted Rating: [1]
# Interogartive

# %%
m3=dt.predict(prt)
print("Predicted Rating:",m3)
if m3==0:
  print("Exclamatory")
else:
  print("Interogartive")
# Out:
# Predicted Rating: [0]
# Exclamatory

# %%
m4=mnb.predict(prt)
print("Predicted Rating:",m4)
if m4==0:
  print("Exclamatory")
else:
  print("Interogartive")
# Out:
# Predicted Rating: [1]
# Interogartive

# %%
m5=rmfr.predict(prt)
print("Predicted Rating:",m5)
if m5==0:
  print("Exclamatory")
else:
  print("Interogartive")
# Out:
# Predicted Rating: [1]
# Interogartive

# %%
m6=xgb.predict(prt)
print("Predicted Rating:",m6)
if m5==0:
  print("Exclamatory")
else:
  print("Interogartive")
# Out:
# Predicted Rating: [0]
# Interogartive
